# %%
import os
import numpy as np 
# -- local --
from feasibgs import util as UT
from feasibgs import catalogs as Cat
from feasibgs import _inspector as Inspect

# %%
# read in GAMA-Legacy survey
cata = Cat.GamaLegacy()
gleg = cata.Read('g15')
redshift = gleg['gama-spec']['z']

# %%
# read in the spectra of the 5th out of 64 block from the GAMA G15 field
f_spec = ''.join([UT.dat_dir(), 'spectra/' 
                  'GamaLegacy.g15.expSpectra.darksky.seed1.exptime300.5of64blocks.fits'])
f_zbest = ''.join([UT.dat_dir(), 'redrock/'
                   'GamaLegacy.g15.expSpectra.darksky.seed1.exptime300.5of64blocks.redrock.fits'])
f_zbest_arch = ''.join([UT.dat_dir(), 'redrock/'
                   'GamaLegacy.g15.expSpectra.darksky.seed1.exptime300.5of64blocks.redrock.archetypetest.fits'])

# %%
f_index = ''.join([UT.dat_dir(), 'spectra/', 
                   'GamaLegacy.g15.expSpectra.darksky.seed1.exptime300.5of64blocks.index'])
index = np.loadtxt(f_index, unpack=True, usecols=[0], dtype='i')

# %%
z_true = redshift[index]

# %%
insp = Inspect.load_spectra(f_spec, zbestfile=f_zbest)
# Out:
#  including 0 ELG, 0 LRG, 0 QSO, 1000 BGS, 0 MWS
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="35135816-aed8-431e-a4d3-cf48e23fc1fe">Loading BokehJS ...</span>
#     </div>

# %%
zwarn = (insp.zbest['ZWARN'] != 0)
zfail = (np.abs(insp.zbest['Z'] - z_true)/(1.+z_true) > 0.003)
print('%i ZWARN != 0' % np.sum(zwarn))
print('%i redshift failures' % np.sum(zfail))
# Out:
# 5 ZWARN != 0
# 32 redshift failures

# %%
insp.plot()
insp.select(insp.zbest['TARGETID'][zwarn])
# Out:
# <style>.container { width:100% !important; }</style>
# <div class="bk-root">
#     <div class="bk-plotdiv" id="d0763b41-335d-4713-80da-7517ccd74271"></div>
# </div>
# HBox(children=(Button(description=u'prev', layout=Layout(width=u'60px'), style=ButtonStyle(), tooltip=u'Go to previous target'), Button(button_style=u'warning', description=u'flag', layout=Layout(width=u'60px'), style=ButtonStyle(), tooltip=u'Flag for more inspection'), Button(description=u'bad', layout=Layout(width=u'60px'), style=ButtonStyle(button_color='gold'), tooltip=u'Bad data (e.g. low-S/N)'), Button(button_style=u'danger', description=u'no', layout=Layout(width=u'60px'), style=ButtonStyle(), tooltip=u'Redshift is not correct'), Button(button_style=u'primary', description=u'maybe', layout=Layout(width=u'60px'), style=ButtonStyle(), tooltip=u'Uncertain if redshift is correct'), Button(button_style=u'success', description=u'yes', layout=Layout(width=u'60px'), style=ButtonStyle(), tooltip=u'Confident that redshift is correct'), Button(description=u'next', layout=Layout(width=u'60px'), style=ButtonStyle(), tooltip=u'Skip to next target without recording yes/no/maybe')))
# <script>$('.widget-area .prompt .close').hide()</script>
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-b409334c9861> in <module>()
#       1 insp.plot()
# ----> 2 insp.select(insp.zbest['TARGETID'][zwarn])
#
# astropy/table/_column_mixins.pyx in astropy.table._column_mixins._ColumnGetitemShim.__getitem__()
#
# astropy/table/_column_mixins.pyx in astropy.table._column_mixins.base_getitem()
#
# astropy/table/_column_mixins.pyx in astropy.table._column_mixins.column_getitem()
#
# IndexError: boolean index did not match indexed array along dimension 0; dimension is 5 but corresponding boolean dimension is 1000
